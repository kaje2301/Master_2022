# %%
import s3fs
import xarray as xr
import numpy as np 
import matplotlib.pyplot as plt 
import math
import zarr

# %%
fsg = s3fs.S3FileSystem(anon=False,
      client_kwargs={
         'endpoint_url': 'https://karen.uiogeo-apps.sigma2.no'
      })

# %%
fsg.ls('data')
# Out:
# ['data/CREG12.L75-REF08_mask.nc',
#  'data/CREG12.L75-REF08_mesh_hgr.nc',
#  'data/CREG12.L75-REF08_mesh_zgr.zarr',
#  'data/PC-data',
#  'data/PCz.zarr',
#  'data/PCz_123_20m',
#  'data/bathym.nc',
#  'data/lat_lon_scalar.zarr',
#  'data/mooring_barents',
#  'data/mooring_beaufort',
#  'data/mooring_lofoten',
#  'data/mooring_yermark',
#  'data/moorings_',
#  'data/moorings_RCM',
#  'data/moorings_chukchi_sea',
#  'data/quiver-data',
#  'data/smooth_grid_karen.nc',
#  'data/u_names.nc',
#  'data/v_names.nc',
#  'data/vel',
#  'data/vel_dataIII.zarr']

# %%
data_path =  's3://data/CREG12.L75-REF08_mesh_zgr.zarr'

# %%
store = s3fs.S3Map(root=data_path, s3=fsg, check=False)

# %%
ds = xr.open_zarr(store=store, consolidated=True)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (t: 1, x: 1580, y: 1801, z: 75)
# Dimensions without coordinates: t, x, y, z
# Data variables: (12/19)
#     e3t_0         (t, z, y, x) float64 dask.array<chunksize=(1, 75, 1801, 1580), meta=np.ndarray>
#     e3t_1d        (t, z) float64 dask.array<chunksize=(1, 75), meta=np.ndarray>
#     e3u_0         (t, z, y, x) float64 dask.array<chunksize=(1, 75, 1801, 1580), meta=np.ndarray>
#     e3v_0         (t, z, y, x) float64 dask.array<chunksize=(1, 75, 1801, 1580), meta=np.ndarray>
#     e3w_0         (t, z, y, x) float64 dask.array<chunksize=(1, 75, 1801, 1580), meta=np.ndarray>
#     e3w_1d        (t, z) float64 dask.array<chunksize=(1, 75), meta=np.ndarray>
#     ...            ...
#     mbathy        (t, y, x) int16 dask.array<chunksize=(1, 1801, 1580), meta=np.ndarray>
#     misf          (t, y, x) int16 dask.array<chunksize=(1, 1801, 1580), meta=np.ndarray>
#     nav_lat       (y, x) float32 dask.array<chunksize=(1801, 1580), meta=np.ndarray>
# ...

# %%
dyp = np.zeros(75, dtype=int)

# %%
for i in range(len(dyp)):
    d = ds.gdept_1d[0,i].values #gdepth_1d
    print(d)
    dyp[i] = d
# Out:
# 0.505760017002558
# 1.5558553038467835
# 2.6676817536726958
# 3.856279741653907
# 5.140361251044396
# 6.543033618686877
# 8.092518387897599
# 9.822750430868382
# 11.773679478971644
# 13.991038002355708
# 16.525321538313165
# 19.429802752345495
# 22.757616206246894
# 26.558300889521433
# 30.87456180433992
# 35.740204689053826
# 41.1800247475835
# 47.21189406745384
# 53.8506372116824
# 61.11284018758897
# 69.02168385704431
# 77.61116175088227
# 86.9294253509072
# 97.04131256482219
# 108.03028088956239
# 120.00000107921005
# 133.0758224151375
# 147.40624497594365
# 163.16445642684175
# 180.5499222552371
# 199.78996030338772
# 221.14118008862374
# 244.89062171303277
# 271.3563867497288
# 300.88751541344794
# 333.8628343934264
# 370.68848448344625
# 411.79384543190145
# 457.625617393413
# 508.63990359049825
# 565.2922735880123
# 628.0259704911632
# 697.2586477464497
# 773.3682589718316
# 856.6789423505214
# 947.4478970895176
# 1045.8543018703663
# 1151.9912450124436
# 1265.861416986486
# ...

# %%
dyp = xr.DataArray(dyp,name='depth')   
#zarr.save('data/dyp.zarr')    
print(dyp[22])
# Out:
# <xarray.DataArray 'depth' ()>
# array(86)

# %%
# Out:
# <xarray.DataArray 'depth' ()>
# array(9)
